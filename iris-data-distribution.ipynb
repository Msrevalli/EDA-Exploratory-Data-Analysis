# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
data_df = pd.read_csv("https://raw.githubusercontent.com/venky14/Machine-Learning-with-Iris-Dataset/master/Iris.csv")

# %%
data =  data_df.copy()

# %%
data
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
data.isnull()
# Out:
#         Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 0    False          False         False          False         False    False
# 1    False          False         False          False         False    False
# 2    False          False         False          False         False    False
# 3    False          False         False          False         False    False
# 4    False          False         False          False         False    False
# ..     ...            ...           ...            ...           ...      ...
# 145  False          False         False          False         False    False
# 146  False          False         False          False         False    False
# 147  False          False         False          False         False    False
# 148  False          False         False          False         False    False
# 149  False          False         False          False         False    False
#
# [150 rows x 6 columns]

# %%
data.isnull().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
data.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
sns.kdeplot(data['SepalLengthCm'], color='b', shade=True, label='sepal_length')
# Out:
# <Axes: xlabel='SepalLengthCm', ylabel='Density'>

# %%
sns.histplot(data['SepalLengthCm'], color='b', label='sepal_length',kde=True)
# Out:
# <Axes: xlabel='SepalLengthCm', ylabel='Count'>

# %%
sns.barplot(x='Species' ,y='SepalLengthCm',data=data)
# Out:
# <Axes: xlabel='Species', ylabel='SepalLengthCm'>

# %%
np.std(data_df['SepalLengthCm'])
# Out:
# 0.8253012917851409

# %%
np.var(data_df['SepalLengthCm'])
# Out:
# 0.6811222222222222

# %%
st.variance(data_df['SepalLengthCm'])
# Out:
# 0.6856935123042506

# %%
st.pvariance(data_df['SepalLengthCm'])
# Out:
# 0.6811222222222223

# %%
st.mode(data_df['SepalLengthCm'])
# Out:
# 5.0

# %%
np.median(data_df['SepalLengthCm'])
# Out:
# 5.8

# %%
stats.mode(data_df['SepalLengthCm'])
# Out:
# ModeResult(mode=5.0, count=10)

# %%
np.percentile(data_df['SepalLengthCm'],[25])
# Out:
# array([5.1])

# %%
np.percentile(data_df['SepalLengthCm'],[50])
# Out:
# array([5.8])

# %%
np.percentile(data_df['SepalLengthCm'],[75])
# Out:
# array([6.4])

# %%
np.percentile(data_df['SepalLengthCm'],[25,50,75,100])
# Out:
# array([5.1, 5.8, 6.4, 7.9])

# %%
[Q1,Q2,Q3,Q4]=np.percentile(data_df['SepalLengthCm'],[25,50,75,100])

# %%
IQR=Q3-Q1

# %%
IQR
# Out:
# 1.3000000000000007

# %%
sns.boxplot(data_df['SepalLengthCm'])
# Out:
# <Axes: >

# %%
test2 = data_df['SepalLengthCm']
test2.loc[len(test2)] = 10
sns.boxplot(test2)
# Out:
# <Axes: >

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
# Exclude non-numeric columns from correlation calculation
numeric_df = data_df.select_dtypes(include=['number'])
correlation_matrix = numeric_df.corr()
numeric_df.corr()
# Out:
#                      Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  \
# Id             1.000000       0.716676     -0.397729       0.882747
# SepalLengthCm  0.716676       1.000000     -0.109369       0.871754
# SepalWidthCm  -0.397729      -0.109369      1.000000      -0.420516
# PetalLengthCm  0.882747       0.871754     -0.420516       1.000000
# PetalWidthCm   0.899759       0.817954     -0.356544       0.962757
#
#                PetalWidthCm
# Id                 0.899759
# SepalLengthCm      0.817954
# SepalWidthCm      -0.356544
# PetalLengthCm      0.962757
# PetalWidthCm       1.000000

# %%
sns.scatterplot(x=data_df['PetalWidthCm'],y=data_df['PetalLengthCm'])
# Out:
# <Axes: xlabel='PetalWidthCm', ylabel='PetalLengthCm'>

# %%
sns.scatterplot(x=data_df['SepalWidthCm'],y=data_df['SepalLengthCm'])
# Out:
# <Axes: xlabel='SepalWidthCm', ylabel='SepalLengthCm'>

# %%
sns.histplot(data_df['SepalLengthCm'],kde=True)
# Out:
# c:\Users\DELL\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='SepalLengthCm', ylabel='Count'>

# %%
sm.qqplot(data_df['SepalLengthCm'],line='s')

# %%
sns.histplot(data_df['SepalWidthCm'],kde=True)
# Out:
# c:\Users\DELL\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='SepalWidthCm', ylabel='Count'>

# %%
sm.qqplot(data_df['SepalWidthCm'],line='s')

# %%
sns.histplot(data_df['PetalLengthCm'],kde=True)
# Out:
# c:\Users\DELL\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='PetalLengthCm', ylabel='Count'>

# %%
sm.qqplot(data_df['PetalLengthCm'],line='s')

# %%
sns.histplot(data_df['PetalWidthCm'],kde=True)
# Out:
# c:\Users\DELL\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='PetalWidthCm', ylabel='Count'>

# %%
sm.qqplot(data_df['PetalWidthCm'],line='s')

# %%
pip install pydantic --user
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from pandas_profiling import ProfileReport
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 from pandas_profiling import ProfileReport
#
# ModuleNotFoundError: No module named 'pandas_profiling'

# %%
pip install pydantic==1.8.2
# Out:
# ...
#   Obtaining dependency information for pydantic==1.8.2 from https://files.pythonhosted.org/packages/ff/74/54e030641601112309f6d2af620774e9080f99c7a15742fc6a0b170c4076/pydantic-1.8.2-py3-none-any.whl.metadata
# ...
#      ---------------------------------------- 0.0/103.1 kB ? eta -:--:--
#      --- ------------------------------------ 10.2/103.1 kB ? eta -:--:--
#      -------------- ---------------------- 41.0/103.1 kB 393.8 kB/s eta 0:00:01
#      -----------------------------------  102.4/103.1 kB 737.3 kB/s eta 0:00:01
#      ------------------------------------ 103.1/103.1 kB 595.4 kB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/126.0 kB ? eta -:--:--
#    ---------------------------------------- 126.0/126.0 kB 7.2 MB/s eta 0:00:00
# ...
#   Attempting uninstall: pydantic
#     Found existing installation: pydantic 2.7.1
#     Uninstalling pydantic-2.7.1:
#       Successfully uninstalled pydantic-2.7.1
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...

# %%
pip install --upgrade pydantic
# Out:
# ...
#   Obtaining dependency information for pydantic from https://files.pythonhosted.org/packages/ed/76/9a17032880ed27f2dbd490c77a3431cbc80f47ba81534131de3c2846e736/pydantic-2.7.1-py3-none-any.whl.metadata
#   Using cached pydantic-2.7.1-py3-none-any.whl.metadata (107 kB)
# ...
# Using cached pydantic-2.7.1-py3-none-any.whl (409 kB)
# ...
#   Attempting uninstall: pydantic
#     Found existing installation: pydantic 1.8.2
#     Uninstalling pydantic-1.8.2:
#       Successfully uninstalled pydantic-1.8.2
# ...
# Note: you may need to restart the kernel to use updated packages.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# anaconda-cloud-auth 0.1.3 requires pydantic<2.0, but you have pydantic 2.7.1 which is incompatible.
